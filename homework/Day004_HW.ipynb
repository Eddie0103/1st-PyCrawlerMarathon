# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
import json

r = requests.get('https://api.github.com/events')

print('len:: \nr.text:{0} \njson:{1}'.format(len(r.text), len(json.loads(r.text))))
print('type:: \nr.text:{0} \njson:{1}'.format(type(r.text), type(json.loads(r.text))))
# Out:
# len::
# r.text:41325
# json:30
# type::
# r.text:<class 'str'>
# json:<class 'list'>

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
res = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
print(r.text)
# Out:
# [{"id":"11034728222","type":"PushEvent","actor":{"id":48861166,"login":"Kaeje1ous","display_login":"Kaeje1ous","gravatar_id":"","url":"https://api.github.com/users/Kaeje1ous","avatar_url":"https://avatars.githubusercontent.com/u/48861166?"},"repo":{"id":225158046,"name":"Kaeje1ous/repair-design","url":"https://api.github.com/repos/Kaeje1ous/repair-design"},"payload":{"push_id":4367515639,"size":6,"distinct_size":6,"ref":"refs/heads/master","head":"18bc6664e5851e9bd1757f26ab34414f313d36a4","before":"28aaffd7b91c8ef17735ed5cb42a065fe1142351","commits":[{"sha":"880c91bba642ca3432ad1e0fbae9e5bdd4b3ca1b","author":{"email":"52853794+Kaejelous@users.noreply.github.com","name":"Kaejelous"},"message":"feat: add font(futura) in project","distinct":true,"url":"https://api.github.com/repos/Kaeje1ous/repair-design/commits/880c91bba642ca3432ad1e0fbae9e5bdd4b3ca1b"},{"sha":"a2d59943dc5ef1a6bd74afb16db5e988691c5231","author":{"email":"52853794+Kaejelous@users.noreply.github.com","name":"Kaejelous"},"message":"feat: add FuturaBook & FuturaDemi fonts","distinct":true,"url":"https://api.github.com/repos/Kaeje1ous/repair-design/commits/a2d59943dc5ef1a6bd74afb16db5e988691c5231"},{"sha":"0dc1f4aef026cd8fdba3a373d1db39b819aab73b","author":{"email":"52853794+Kaejelous@users.noreply.github.com","name":"Kaejelous"},"message":"feat: add intagram button","distinct":true,"url":"https://api.github.com/repos/Kaeje1ous/repair-design/commits/0dc1f4aef026cd8fdba3a373d1db39b819aab73b"},{"sha":"83dbc0d7d9e0a147de236cd652520a557e6b087a","author":{"email":"52853794+Kaejelous@users.noreply.github.com","name":"Kaejelous"},"message":"refact: fixed header position","distinct":true,"url":"https://api.github.com/repos/Kaeje1ous/repair-design/commits/83dbc0d7d9e0a147de236cd652520a557e6b087a"},{"sha":"9a06154f8ad949eaf030141fbe00b97cf4302ec7","author":{"email":"52853794+Kaejelous@users.noreply.github.com","name":"Kaejelous"},"message":"feat: add box-sizing border box","distinct":true,"url":"https://api.github.com/repos/Kaeje1ous/repair-design/commits/9a06154f8ad949eaf030141fbe00b97cf4302ec7"},{"sha":"18bc6664e5851e9bd1757f26ab34414f313d36a4","author":{"email":"52853794+Kaejelous@users.noreply.github.com","name":"Kaejelous"},"message":"feat: add hero content styles","distinct":true,"url":"https://api.github.com/repos/Kaeje1ous/repair-design/commits/18bc6664e5851e9bd1757f26ab34414f313d36a4"}]},"public":true,"created_at":"2019-12-07T08:06:18Z"},{"id":"11034728220","type":"PushEvent","actor":{"id":55362690,"login":"Lianghai-Yang","display_login":"Lianghai-Yang","gravatar_id":"","url":"https://api.github.com/users/Lianghai-Yang","avatar_url":"https://avatars.githubusercontent.com/u/55362690?"},"repo":{"id":214279692,"name":"Lianghai-Yang/Jinlile","url":"https://api.github.com/repos/Lianghai-Yang/Jinlile"},"payload":{"push_id":4367515637,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"abca2240fd8655b263ea89a3c165f8c413fded8f","before":"15de5fa2533b59834e62dfc307b8c131155be37d","commits":[{"sha":"abca2240fd8655b263ea89a3c165f8c413fded8f","author":{"email":"yanglianghai1994@gmail.com","name":"Lianghai-Yang"},"message":"add message type for toast","distinct":true,"url":"https://api.github.com/repos/Lianghai-Yang/Jinlile/commits/abca2240fd8655b263ea89a3c165f8c413fded8f"}]},"public":true,"created_at":"2019-12-07T08:06:18Z"},{"id":"11034728218","type":"PushEvent","actor":{"id":57826032,"login":"jaccobkii","display_login":"jaccobkii","gravatar_id":"","url":"https://api.github.com/users/jaccobkii","avatar_url":"https://avatars.githubusercontent.com/u/57826032?"},"repo":{"id":224461173,"name":"zeno-hentai/zht-client-browser","url":"https://api.github.com/repos/zeno-hentai/zht-client-browser"},"payload":{"push_id":4367515636,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"7200a439a82d40730da460a585eaec581c7ba900","before":"717cb82a0199eb0906a9b0db5b1700f1b13f2670","commits":[{"sha":"7200a439a82d40730da460a585eaec581c7ba900","author":{"email":"jaccobkii@gmail.com ...

# %%
print(json.loads(r.text))
# Out:
# [{'id': '11034728222', 'type': 'PushEvent', 'actor': {'id': 48861166, 'login': 'Kaeje1ous', 'display_login': 'Kaeje1ous', 'gravatar_id': '', 'url': 'https://api.github.com/users/Kaeje1ous', 'avatar_url': 'https://avatars.githubusercontent.com/u/48861166?'}, 'repo': {'id': 225158046, 'name': 'Kaeje1ous/repair-design', 'url': 'https://api.github.com/repos/Kaeje1ous/repair-design'}, 'payload': {'push_id': 4367515639, 'size': 6, 'distinct_size': 6, 'ref': 'refs/heads/master', 'head': '18bc6664e5851e9bd1757f26ab34414f313d36a4', 'before': '28aaffd7b91c8ef17735ed5cb42a065fe1142351', 'commits': [{'sha': '880c91bba642ca3432ad1e0fbae9e5bdd4b3ca1b', 'author': {'email': '52853794+Kaejelous@users.noreply.github.com', 'name': 'Kaejelous'}, 'message': 'feat: add font(futura) in project', 'distinct': True, 'url': 'https://api.github.com/repos/Kaeje1ous/repair-design/commits/880c91bba642ca3432ad1e0fbae9e5bdd4b3ca1b'}, {'sha': 'a2d59943dc5ef1a6bd74afb16db5e988691c5231', 'author': {'email': '52853794+Kaejelous@users.noreply.github.com', 'name': 'Kaejelous'}, 'message': 'feat: add FuturaBook & FuturaDemi fonts', 'distinct': True, 'url': 'https://api.github.com/repos/Kaeje1ous/repair-design/commits/a2d59943dc5ef1a6bd74afb16db5e988691c5231'}, {'sha': '0dc1f4aef026cd8fdba3a373d1db39b819aab73b', 'author': {'email': '52853794+Kaejelous@users.noreply.github.com', 'name': 'Kaejelous'}, 'message': 'feat: add intagram button', 'distinct': True, 'url': 'https://api.github.com/repos/Kaeje1ous/repair-design/commits/0dc1f4aef026cd8fdba3a373d1db39b819aab73b'}, {'sha': '83dbc0d7d9e0a147de236cd652520a557e6b087a', 'author': {'email': '52853794+Kaejelous@users.noreply.github.com', 'name': 'Kaejelous'}, 'message': 'refact: fixed header position', 'distinct': True, 'url': 'https://api.github.com/repos/Kaeje1ous/repair-design/commits/83dbc0d7d9e0a147de236cd652520a557e6b087a'}, {'sha': '9a06154f8ad949eaf030141fbe00b97cf4302ec7', 'author': {'email': '52853794+Kaejelous@users.noreply.github.com', 'name': 'Kaejelous'}, 'message': 'feat: add box-sizing border box', 'distinct': True, 'url': 'https://api.github.com/repos/Kaeje1ous/repair-design/commits/9a06154f8ad949eaf030141fbe00b97cf4302ec7'}, {'sha': '18bc6664e5851e9bd1757f26ab34414f313d36a4', 'author': {'email': '52853794+Kaejelous@users.noreply.github.com', 'name': 'Kaejelous'}, 'message': 'feat: add hero content styles', 'distinct': True, 'url': 'https://api.github.com/repos/Kaeje1ous/repair-design/commits/18bc6664e5851e9bd1757f26ab34414f313d36a4'}]}, 'public': True, 'created_at': '2019-12-07T08:06:18Z'}, {'id': '11034728220', 'type': 'PushEvent', 'actor': {'id': 55362690, 'login': 'Lianghai-Yang', 'display_login': 'Lianghai-Yang', 'gravatar_id': '', 'url': 'https://api.github.com/users/Lianghai-Yang', 'avatar_url': 'https://avatars.githubusercontent.com/u/55362690?'}, 'repo': {'id': 214279692, 'name': 'Lianghai-Yang/Jinlile', 'url': 'https://api.github.com/repos/Lianghai-Yang/Jinlile'}, 'payload': {'push_id': 4367515637, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': 'abca2240fd8655b263ea89a3c165f8c413fded8f', 'before': '15de5fa2533b59834e62dfc307b8c131155be37d', 'commits': [{'sha': 'abca2240fd8655b263ea89a3c165f8c413fded8f', 'author': {'email': 'yanglianghai1994@gmail.com', 'name': 'Lianghai-Yang'}, 'message': 'add message type for toast', 'distinct': True, 'url': 'https://api.github.com/repos/Lianghai-Yang/Jinlile/commits/abca2240fd8655b263ea89a3c165f8c413fded8f'}]}, 'public': True, 'created_at': '2019-12-07T08:06:18Z'}, {'id': '11034728218', 'type': 'PushEvent', 'actor': {'id': 57826032, 'login': 'jaccobkii', 'display_login': 'jaccobkii', 'gravatar_id': '', 'url': 'https://api.github.com/users/jaccobkii', 'avatar_url': 'https://avatars.githubusercontent.com/u/57826032?'}, 'repo': {'id': 224461173, 'name': 'zeno-hentai/zht-client-browser', 'url': 'https://api.github.com/repos/zeno-hentai/zht-client-browser'}, 'payload': {'push_id': 4367515636, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/ma ...
